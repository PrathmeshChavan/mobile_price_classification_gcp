# %%
# Importing Required Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns' , None)

# %%
# Reading File

df = pd.read_csv("C://Users//admin//Desktop//Mobile_Classification//Dataset//train.csv")

# %%
df.head()   # First 5 records
# Out:
#    battery_power  bluetoth  dual_sim  front_cam  4G  int_memory  mob_weight  \
# 0            842         0         0          1   0           7         188
# 1           1021         1         1          0   1          53         136
# 2            563         1         1          2   1          41         145
# 3            615         1         0          0   0          10         131
# 4           1821         1         0         13   1          44         141
#
#    n_cores  main_cam  px_height  px_width   ram  talk_time  3G  touch_screen  \
# 0        2         2         20       756  2549         19   0             0
# 1        3         6        905      1988  2631          7   1             1
# 2        5         6       1263      1716  2603          9   1             1
# 3        6         9       1216      1786  2769         11   1             0
# 4        2        14       1208      1212  1411         15   1             1
#
#    wifi  price_range
# 0     1            1
# ...

# %%
df.shape   # Count of rows and columns
# Out:
# (2000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   bluetoth       2000 non-null   int64
#  2   dual_sim       2000 non-null   int64
#  3   front_cam      2000 non-null   int64
#  4   4G             2000 non-null   int64
#  5   int_memory     2000 non-null   int64
#  6   mob_weight     2000 non-null   int64
#  7   n_cores        2000 non-null   int64
#  8   main_cam       2000 non-null   int64
#  9   px_height      2000 non-null   int64
#  10  px_width       2000 non-null   int64
#  11  ram            2000 non-null   int64
#  12  talk_time      2000 non-null   int64
#  13  3G             2000 non-null   int64
#  14  touch_screen   2000 non-null   int64
#  15  wifi           2000 non-null   int64
#  16  price_range    2000 non-null   int64
# dtypes: int64(17)
# memory usage: 265.8 KB

# %% [markdown]
# We can see that , Dataset does not contain any null value

# %% [markdown]
# Also all features are in numerical data type , hence dataset does not need any data type conversion

# %%
df.describe()   # Statistical summary of Dataset
# Out:
#        battery_power   bluetoth     dual_sim    front_cam           4G  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     0.509500     4.309500     0.521500
# std       439.418206     0.5001     0.500035     4.341444     0.499662
# min       501.000000     0.0000     0.000000     0.000000     0.000000
# 25%       851.750000     0.0000     0.000000     1.000000     0.000000
# 50%      1226.000000     0.0000     1.000000     3.000000     1.000000
# 75%      1615.250000     1.0000     1.000000     7.000000     1.000000
# max      1998.000000     1.0000     1.000000    19.000000     1.000000
#
#         int_memory   mob_weight      n_cores     main_cam    px_height  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     32.046500   140.249000     4.520500     9.916500   645.108000
# std      18.145715    35.399655     2.287837     6.064315   443.780811
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# bluetoth         0
# dual_sim         0
# front_cam        0
# 4G               0
# int_memory       0
# mob_weight       0
# n_cores          0
# main_cam         0
# px_height        0
# px_width         0
# ram              0
# talk_time        0
# 3G               0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %% [markdown]
# No NULL values...........!

# %% [markdown]
# # EDA

# %%
# Extracting continious columns

for i in df:
    if len(df[i].unique()) > 15:
        print("'" +i+ "'" + ",")
# Out:
# 'battery_power',
# 'front_cam',
# 'int_memory',
# 'mob_weight',
# 'main_cam',
# 'px_height',
# 'px_width',
# 'ram',
# 'talk_time',

# %% [markdown]
# We will check distribution of all these columns

# %%
df_cont = df[['battery_power',
'front_cam',
'int_memory',
'mob_weight',
'main_cam',
'px_height',
'px_width',
'ram',
'talk_time']]

# %% [markdown]
# ### Analysing Distribution of continious features

# %%
sns.pairplot(df_cont , diag_kind='kde')

# %%
plt.figure(figsize=(18,12),facecolor='white')
plotnumber = 1

for column in df_cont:
    ax = plt.subplot(3,3,plotnumber)
    sns.distplot(df_cont[column])
    plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %% [markdown]
# #### Distribution of all continious features follows "Normal Distribution" with Low variance

# %% [markdown]
# ### Detecting Outliers

# %%
plt.figure(figsize=(18,12),facecolor='white')
plotnumber = 1

for column in df_cont:
    ax = plt.subplot(3,3,plotnumber)
    sns.boxplot(df_cont[column])
    plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %% [markdown]
# #### As we can see in boxplot , Dataset does not have outliers

# %% [markdown]
# #### Few datapoints in front camera feature falling away from its 75 percentile

# %% [markdown]
# #### But they can be considered as normal data points

# %% [markdown]
# ### Datsaset is Balanced or Not ?

# %%
sns.countplot(df['price_range'])

# %% [markdown]
# There are 4 Classes in dataset

# %% [markdown]
# 0 --------- All mobiles below 10,000

# %% [markdown]
# 1---------All mobiles between 10,000 - 20,000

# %% [markdown]
# 2---------All mobiles between 20,000 - 30,000

# %% [markdown]
# 3---------All mobiles above 30,0000

# %% [markdown]
# #### A datseet is equally balanced

# %% [markdown]
# #### Hence does not need any type of over or under sampling

# %% [markdown]
# ### Finding Multicollinearity

# %%
plt.figure(figsize=(15 , 8))
sns.heatmap(df.corr() , annot = True)

# %% [markdown]
# Some features like

# %% [markdown]
# front_camera ----- main_camera (65%)

# %% [markdown]
# 4G ----- 3G (57%)

# %% [markdown]
# px_height ----- px_width(51%)

# %% [markdown]
# are corelated with each other

# %% [markdown]
# since the corelation is not so high ex above 80-90% ,

# %% [markdown]
# we will not drop any feature.

# %%
sns.barplot(df['price_range'] , df['ram'])

# %% [markdown]
# there is 92% corelation of ram with target feature price range

# %%
sns.barplot(df['price_range'] , df['battery_power'])

# %% [markdown]
# Higher the battery power ---- higher the price

# %%
sns.countplot(x = df['bluetoth'] ,  hue = df['price_range'])

# %%
for i in df:
    if len(df[i].unique())==2:
        print("'" +i+ "'" + ",")
# Out:
# 'bluetoth',
# 'dual_sim',
# '4G',
# '3G',
# 'touch_screen',
# 'wifi',

# %% [markdown]
# #### Checking categorical features against price range

# %%
df_cat = df[['bluetoth' , 'dual_sim' , '4G' , '3G' , 'touch_screen' , 'wifi']]

# %%
plt.figure(figsize=(18,12),facecolor='white')
plotnumber = 1

for column in df_cat:
    ax = plt.subplot(3,2,plotnumber)
    sns.countplot(x = df_cat[column], hue = df['price_range'])
    plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %% [markdown]
# ### Selecting Best features

# %%
plt.figure(figsize=(15 , 8))
sns.heatmap(df.corr() , annot = True)

# %%
x = df.drop(['price_range'] , axis = 1)
y = df.price_range

# %%
from sklearn.feature_selection import SelectKBest , chi2

features = SelectKBest(score_func = chi2 ,  k = 10)

rank=features.fit(x,y)

dfscores = pd.DataFrame(rank.scores_ , columns=['scores'])

dfcolums = pd.DataFrame(x.columns)

final = pd.concat([dfscores , dfcolums] , axis = 1)

final.nlargest(16 , 'scores')
# Out:
#            scores              0
# 11  931267.519053            ram
# 9    17363.569536      px_height
# 0    14129.866576  battery_power
# 10    9810.586750       px_width
# 6       95.972863     mob_weight
# 5       89.839124     int_memory
# 12      13.236400      talk_time
# 3       10.135166      front_cam
# 8        9.186054       main_cam
# 7        9.097556        n_cores
# 14       1.928429   touch_screen
# 4        1.521572             4G
# 1        0.723232       bluetoth
# 2        0.631011       dual_sim
# 15       0.422091           wifi
# 13       0.327643             3G

# %% [markdown]
# ### selected features are : --

# %% [markdown]
# #### ram

# %% [markdown]
# ####  px_height

# %% [markdown]
# #### battery_power

# %% [markdown]
# #### px_width

# %% [markdown]
# #### mobile_weight

# %% [markdown]
# #### internal_memory

# %%
data = df[['ram' , 'battery_power' , 'int_memory' , 'mob_weight' , 'px_height' , 'px_width' , 'price_range']]

# %%
data.head()
# Out:
#     ram  battery_power  int_memory  mob_weight  px_height  px_width  \
# 0  2549            842           7         188         20       756
# 1  2631           1021          53         136        905      1988
# 2  2603            563          41         145       1263      1716
# 3  2769            615          10         131       1216      1786
# 4  1411           1821          44         141       1208      1212
#
#    price_range
# 0            1
# 1            2
# 2            2
# 3            2
# 4            1

# %%
#data.to_csv("C://Users//admin//Desktop//Mobile_Classification//Data_Preprocessing//raw_data.csv", index = False)

# %%
x = df[['ram' , 'battery_power' , 'int_memory' , 'mob_weight' , 'px_height' , 'px_width']]
y = data.price_range

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(x)
df = pd.DataFrame(data = x_scaled , columns=x.columns)
data = pd.concat([df , y] , axis = 1)

# %%
data.head()
# Out:
#         ram  battery_power  int_memory  mob_weight  px_height  px_width  \
# 0  0.391703      -0.902597   -1.380644    1.349249  -1.408949 -1.146784
# 1  0.467317      -0.495139    1.155024   -0.120059   0.585778  1.704465
# 2  0.441498      -1.537686    0.493546    0.134244   1.392684  1.074968
# 3  0.594569      -1.419319   -1.215274   -0.261339   1.286750  1.236971
# 4 -0.657666       1.325906    0.658915    0.021220   1.268718 -0.091452
#
#    price_range
# 0            1
# 1            2
# 2            2
# 3            2
# 4            1

# %%
#data.to_csv("C://Users//admin//Desktop//Mobile_Classification//Data_Preprocessing//scaled_data.csv", index = False)
